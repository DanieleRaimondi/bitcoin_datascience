# %%
import sys
sys.path.append("/Users/danieleraimondi/bitcoin_datascience/functions")

from functions_MVRV import (
    load_dataframe,
    plot_btcusd_vs_mvrv,
    plot_btcusd_and_mvrv_oscillator,
)

import warnings
warnings.filterwarnings("ignore")


df,mvrv, merged = load_dataframe()
mvrv
# Out:
#             Day      mvrv
# 0    2010-10-09  6.352667
# 1    2010-10-10       NaN
# 2    2010-10-11       NaN
# 3    2010-10-12  6.540772
# 4    2010-10-13       NaN
# ...         ...       ...
# 4949 2024-04-27  2.201456
# 4950 2024-04-28       NaN
# 4951 2024-04-29       NaN
# 4952 2024-04-30       NaN
# 4953 2024-05-01  2.114387
#
# [4954 rows x 2 columns]

# %%
plot_btcusd_vs_mvrv(merged, frac=0.0175)

# %%
plot_btcusd_and_mvrv_oscillator(merged, frac=0.0175, k=0.01)
