# %% [markdown]
# # **Bitcoin Pi Cycle Top Indicator**
#
# The Pi Cycle Top Indicator compares Bitcoin's 111-day moving average against 2x its 350-day moving average. Whenever the 111-day average crosses above the doubled 350-day average, the market has, in every cycle to date, been within days of the eventual cycle top.
#
# ## Data Loading
#
# Bitcoin price is pulled from CoinMetrics (via `functions.fetch_data.fetch_crypto_data`), and both moving averages are computed on top of it.
#
# ## Visualization
#
# BTC price (log scale) together with the 111-day SMA and 2x 350-day SMA; every historical crossover is marked with a vertical line.

# %%
import sys
import sys, os
_base = os.getcwd()
while _base and not os.path.isdir(os.path.join(_base, 'functions')):
    _parent = os.path.dirname(_base)
    if _parent == _base: break
    _base = _parent
if os.path.abspath(_base) not in sys.path:
    sys.path.insert(0, os.path.abspath(_base))
from functions.functions_PiCycleTop import (
    load_dataframe,
    plot_pi_cycle_top
)
import warnings
warnings.filterwarnings("ignore")

df = load_dataframe()
# Out:
# you are using nologin method, data you access may be limited
# ✅ BTC data fetched from CoinMetrics: 6351 rows (last: 2026-05-24)
# 🔄 BTC PriceUSD topped up with Yahoo Finance through 2026-09-18 (118 extra day(s)); other on-chain fields carried forward from 2026-05-23

# %%
plot_pi_cycle_top(df)
