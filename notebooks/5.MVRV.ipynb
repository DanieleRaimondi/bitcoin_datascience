# %%
import sys
sys.path.append("/Users/danieleraimondi/bitcoin_datascience/functions")

from functions_MVRV import (
    load_dataframe,
    plot_btcusd_vs_mvrv,
    plot_btcusd_and_mvrv_oscillator,
)

import warnings
warnings.filterwarnings("ignore")


df,mvrv, merged = load_dataframe()
mvrv
# Out:
#             Day      mvrv
# 0    2010-10-09  6.352667
# 1    2010-10-10       NaN
# 2    2010-10-11       NaN
# 3    2010-10-12  6.538855
# 4    2010-10-13       NaN
# ...         ...       ...
# 4973 2024-05-21       NaN
# 4974 2024-05-22  2.385442
# 4975 2024-05-23       NaN
# 4976 2024-05-24       NaN
# 4977 2024-05-25  2.345602
#
# [4978 rows x 2 columns]

# %%
plot_btcusd_vs_mvrv(merged, frac=0.0175)

# %%
plot_btcusd_and_mvrv_oscillator(merged, frac=0.0175, k=0.01)
