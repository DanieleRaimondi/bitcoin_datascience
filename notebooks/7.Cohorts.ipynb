# %%
import sys
sys.path.append("/Users/danieleraimondi/bitcoin_datascience/functions")

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import numpy as np
import pandas as pd
from datetime import datetime

from functions_cohorts import plot_cohorts

# %% [markdown]
# # BITCOIN

# %%
btc_data = pd.read_csv("/Users/danieleraimondi/bitcoin_datascience/functions/data/btc.csv", parse_dates=["time"])
plot_cohorts(btc_data, "PriceUSD", "BTC")

# %% [markdown]
# # LITECOIN

# %%
ltc_data = pd.read_csv("/Users/danieleraimondi/bitcoin_datascience/functions/data/ltc.csv", parse_dates=["time"])
plot_cohorts(ltc_data, "PriceUSD", "LTC")
