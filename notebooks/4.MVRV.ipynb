# %%
import sys
sys.path.append("/Users/danieleraimondi/bitcoin_datascience/functions")

from functions_MVRV import (
    load_dataframe,
    plot_btcusd_vs_mvrv,
    plot_btcusd_and_mvrv_oscillator,
)

import warnings
warnings.filterwarnings("ignore")


df,mvrv, merged = load_dataframe()
mvrv
# Out:
#             Day      mvrv
# 0    2010-10-09  6.352667
# 1    2010-10-10       NaN
# 2    2010-10-11       NaN
# 3    2010-10-12  6.539813
# 4    2010-10-13       NaN
# ...         ...       ...
# 4963 2024-05-11       NaN
# 4964 2024-05-12  2.110738
# 4965 2024-05-13       NaN
# 4966 2024-05-14       NaN
# 4967 2024-05-15  2.173217
#
# [4968 rows x 2 columns]

# %%
plot_btcusd_vs_mvrv(merged, frac=0.0175)

# %%
plot_btcusd_and_mvrv_oscillator(merged, frac=0.0175, k=0.01)
